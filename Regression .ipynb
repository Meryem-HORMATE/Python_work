# %%
import pandas as pd
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt 
from matplotlib import style
# %matplotlib inline
import seaborn as sns

df = pd.read_csv('kc_house_data.csv')
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.tail()
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21608        1530              0      2009             0    98103  47.6993
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
#df.describe()
df.describe().T
# Out:
#                  count          mean           std           min  \
# id             21613.0  4.580302e+09  2.876566e+09  1.000102e+06
# price          21613.0  5.400881e+05  3.671272e+05  7.500000e+04
# bedrooms       21613.0  3.370842e+00  9.300618e-01  0.000000e+00
# bathrooms      21613.0  2.114757e+00  7.701632e-01  0.000000e+00
# sqft_living    21613.0  2.079900e+03  9.184409e+02  2.900000e+02
# sqft_lot       21613.0  1.510697e+04  4.142051e+04  5.200000e+02
# floors         21613.0  1.494309e+00  5.399889e-01  1.000000e+00
# waterfront     21613.0  7.541757e-03  8.651720e-02  0.000000e+00
# view           21613.0  2.343034e-01  7.663176e-01  0.000000e+00
# condition      21613.0  3.409430e+00  6.507430e-01  1.000000e+00
# grade          21613.0  7.656873e+00  1.175459e+00  1.000000e+00
# sqft_above     21613.0  1.788391e+03  8.280910e+02  2.900000e+02
# sqft_basement  21613.0  2.915090e+02  4.425750e+02  0.000000e+00
# ...

# %%
df.shape
# Out:
# (21613, 21)

# %%
#print(pd.isnull(df).sum())
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
total=df.isnull().sum().sort_values(ascending=False)
perc1=df.isnull().sum()/df.isnull().count()*100
perc2=(round(perc1,1)).sort_values(ascending=False)
missing_data=pd.concat([total,perc2], axis=1, keys=['Total','%'])
missing_data.head()
# Out:
#             Total    %
# sqft_lot15      0  0.0
# view            0  0.0
# date            0  0.0
# price           0  0.0
# bedrooms        0  0.0

# %%
df.columns.values
# Out:
# array(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated',
#        'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype=object)

# %%
df=df.drop(["id"],axis=1)

# %%
correlation = df.corr(method='pearson')
columns = correlation.nlargest(10, 'price').index
columns
# Out:
# Index(['price', 'sqft_living', 'grade', 'sqft_above', 'sqft_living15',
#        'bathrooms', 'view', 'sqft_basement', 'bedrooms', 'lat'],
#       dtype='object')

# %%
correlation_map = np.corrcoef(df[columns].values.T)
sns.set(font_scale=1.0)
heatmap = sns.heatmap(correlation_map, cbar=True, annot=True, square=True, fmt='.2f', yticklabels=columns.values, xticklabels=columns.values)

plt.show()

#From the earlier data.describe() output, I observed that the values of 2 variables - price and sqft_living - are large and will affect the absolute numbers of the regression model. To manage this, I will normalise the data using log.


'''sqft_living, sqft_above and sqft_basement were moderately/strongly associated with price. 
Paerson r was equal to 0.70, 0.61 and 0.41, respectively. 
The 3 variables were also strongly related to each other as sqft_living = sqft_above and sqft_basement.
sqft_living15, the average house square footage of the 15 closest neighbors, 
was also strongly related to price (r = 0.59) . However, when controlling for sqft_living,
the relationship disappeared ( r=0.06 ).
sqft_lot, sqft_lot15 (average lot size of the 15 closest houses) and yr_built were poorly related to price.
The three dichotomous variables (waterfront, basement_present, renovated) were associated with price. 
The associations were small (r < 0.3)
Five of the ordinal parameters (bedrooms, bathrooms, floors, views, grade) 
were also moderately to strongly associated with price.'''
# Out:
# 'sqft_living, sqft_above and sqft_basement were moderately/strongly associated with price. \nPaerson r was equal to 0.70, 0.61 and 0.41, respectively. \nThe 3 variables were also strongly related to each other as sqft_living = sqft_above and sqft_basement.\nsqft_living15, the average house square footage of the 15 closest neighbors, \nwas also strongly related to price (r = 0.59) . However, when controlling for sqft_living,\nthe relationship disappeared ( r=0.06 ).\nsqft_lot, sqft_lot15 (average lot size of the 15 closest houses) and yr_built were poorly related to price.\nThe three dichotomous variables (waterfront, basement_present, renovated) were associated with price. \nThe associations were small (r < 0.3)\nFive of the ordinal parameters (bedrooms, bathrooms, floors, views, grade) \nwere also moderately to strongly associated with price.'

# %%
plt.figure(figsize=(10,10))
sns.kdeplot(df["price"],shade=True);

# %%
sns.boxplot(df['price'], orient='vertical');

# %%
sns.violinplot(df['price'], orient='vertical');

# %%
sns.countplot(df["bedrooms"]);

# %%
df.corr()["price"].sort_values()
# Out:
# zipcode         -0.053203
# long             0.021626
# condition        0.036362
# yr_built         0.054012
# sqft_lot15       0.082447
# sqft_lot         0.089661
# yr_renovated     0.126434
# floors           0.256794
# waterfront       0.266369
# lat              0.307003
# bedrooms         0.308350
# sqft_basement    0.323816
# view             0.397293
# bathrooms        0.525138
# sqft_living15    0.585379
# sqft_above       0.605567
# grade            0.667434
# sqft_living      0.702035
# price            1.000000
# Name: price, dtype: float64

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x="price",y="sqft_living",data=df);

# %%
plt.figure(figsize=(10,10))
sns.boxplot(x="bedrooms",y="price",data=df);

# %%
sns.catplot(x="bedrooms",y="price", kind="boxen",data=df);

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x="price",y="long",data=df);

# %%
sns.catplot(x="price",y="long", kind="boxen",data=df);

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x="price",y="lat",data=df);

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x="long",y="lat",data=df,hue="price");

# %%
df.sort_values("price",ascending=False).head(20)
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 7252   20141013T000000  7700000.0         6       8.00        12050     27600
# 3914   20140611T000000  7062500.0         5       4.50        10040     37325
# 9254   20140919T000000  6885000.0         6       7.75         9890     31374
# 4411   20140804T000000  5570000.0         5       5.75         9200     35069
# 1448   20150413T000000  5350000.0         5       5.00         8000     23985
# 1315   20150413T000000  5300000.0         6       6.00         7390     24829
# 1164   20141020T000000  5110800.0         5       5.25         8010     45517
# 8092   20140617T000000  4668000.0         5       6.75         9640     13068
# 2626   20140815T000000  4500000.0         5       5.50         6640     40014
# 8638   20140618T000000  4489000.0         4       3.00         6430     27517
# 12370  20150506T000000  4208000.0         5       6.00         7440     21540
# ...

# %%
len(df)*0.01
# Out:
# 216.13

# %%
non_top_one_percent = df.sort_values("price",ascending=False).iloc[216:]

# %%
sns.relplot(x="long",y="lat", hue="price", data=non_top_one_percent);

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x="long",y="lat",data=non_top_one_percent,edgecolor=None,hue="price",alpha=0.2,palette='RdYlGn');

# %%
sns.boxplot(x="waterfront",y="price",data=df);

# %%
sns.catplot(x="waterfront",y="price", kind="boxen",data=df);

# %%
df["date"] = pd.to_datetime(df["date"])

# %%
def year_extraction(date):
    return date.year

# %%
df["year"] = df["date"].apply(lambda date: date.year)

# %%
df["month"] = df["date"].apply(lambda date: date.month)

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x="month",y="price",data=df);

# %%
df.groupby('month').mean()["price"].plot();

# %%
df.groupby('year').mean()["price"].plot();

# %%
df.drop("date",axis=1,inplace=True)

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  ...  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7  ...              0      1955             0
# 1     0          3      7  ...            400      1951          1991
# 2     0          3      6  ...              0      1933             0
# 3     0          5      7  ...            910      1965             0
# 4     0          3      8  ...              0      1987             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15  year  month
# ...

# %%
df["zipcode"].value_counts()
# Out:
# 98103    602
# 98038    590
# 98115    583
# 98052    574
# 98117    553
#         ...
# 98102    105
# 98010    100
# 98024     81
# 98148     57
# 98039     50
# Name: zipcode, Length: 70, dtype: int64

# %%
df.drop("zipcode",axis=1,inplace=True)

# %%
df["yr_renovated"].value_counts()
# Out:
# 0       20699
# 2014       91
# 2013       37
# 2003       36
# 2000       35
#         ...
# 1934        1
# 1959        1
# 1951        1
# 1948        1
# 1944        1
# Name: yr_renovated, Length: 70, dtype: int64

# %%
df["sqft_basement"].value_counts()
# Out:
# 0       13126
# 600       221
# 700       218
# 500       214
# 800       206
#         ...
# 792         1
# 2590        1
# 935         1
# 2390        1
# 248         1
# Name: sqft_basement, Length: 306, dtype: int64

# %%
#X = df.drop("price",axis=1).values
#y = df["price"].values

#space=df['sqft_living']
#price=df['price']

X = np.array(df['sqft_living']).reshape(-1, 1)
y = np.array(df['price'])

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error,explained_variance_score
from sklearn import metrics


X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=405)

model=LinearRegression()   #build linear regression model
model.fit(X_train,y_train)  #fitting the training data
pred=model.predict(X_test) #testing our model’s performance

# %%
print("MSE : ", mean_squared_error(y_test,pred))
print("R squared : ", metrics.r2_score(y_test,pred))
# Out:
# MSE :  67193635914.06649
# R squared :  0.48986903605820364

# %%
np.sqrt(mean_squared_error(y_test,pred))
# Out:
# 259217.3526484415

# %%
mean_absolute_error(y_test,pred)
# Out:
# 174294.63498200238

# %%
explained_variance_score(y_test,pred)
# Out:
# 0.4900118804880572

# %%
#Visualizing the training Test Results 
plt.scatter(X_train, y_train, color= 'red')
plt.plot(X_train, model.predict(X_train), color = 'blue')
plt.title ("Visuals for Training Dataset")
plt.xlabel("Space")
plt.ylabel("Price")
plt.show()

# %%
#Visualizing the Test Results 
plt.scatter(X_test, y_test, color= 'red')
plt.plot(X_train, model.predict(X_train), color = 'blue')
plt.title("Visuals for Test DataSet")
plt.xlabel("Space")
plt.ylabel("Price")
plt.show()

# %%
df["price"].describe().T
# Out:
# count    2.161300e+04
# mean     5.400881e+05
# std      3.671272e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
plt.figure(figsize=(12,6))
plt.scatter(y_test,pred)
plt.plot(y_test,y_test,"r");

# %%
print(df.dtypes)
# Out:
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# year               int64
# month              int64
# dtype: object

# %%
#Multi-linear Regression Code

X= df.iloc[:,1:].values
y = df.iloc[:,0].values

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=405)

model=LinearRegression()   
model.fit(X_train,y_train)  
pred=model.predict(X_test)

# %%
print("MSE : ", mean_squared_error(y_test,pred))
print("R squared : ", metrics.r2_score(y_test,pred))
# Out:
# MSE :  39822181897.16362
# R squared :  0.6976718440501457

# %%
'''compare = pd.DataFrame({'Prediction': pred, 'Test Data' : y_test})
compare.head(10)'''
# Out:
# "compare = pd.DataFrame({'Prediction': pred, 'Test Data' : y_test})\ncompare.head(10)"

# %%
'''actual_y_test = np.exp(y_test)
actual_predicted = np.exp(pred)
diff = abs(actual_y_test - actual_predicted)

compare_actual = pd.DataFrame({'Test Data': actual_y_test, 'Predicted Price' : actual_predicted, 'Difference' : diff})
#compare_actual = compare_actual.astype(int)
compare_actual.head(5)'''
# Out:
# "actual_y_test = np.exp(y_test)\nactual_predicted = np.exp(pred)\ndiff = abs(actual_y_test - actual_predicted)\n\ncompare_actual = pd.DataFrame({'Test Data': actual_y_test, 'Predicted Price' : actual_predicted, 'Difference' : diff})\n#compare_actual = compare_actual.astype(int)\ncompare_actual.head(5)"

# %%
#Polynomial Regression

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures 
from sklearn import metrics


x= df.iloc[:,1:].values
y= df.iloc[:,0].values

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=405)  #splitting data
lg=LinearRegression()
poly=PolynomialFeatures(degree=3)

x_train_fit = poly.fit_transform(x_train) #transforming our input data
lg.fit(x_train_fit, y_train)
x_test_ = poly.fit_transform(x_test)
predicted = lg.predict(x_test_)

# %%
print("MSE: ", metrics.mean_squared_error(y_test, predicted))
print("R squared: ", metrics.r2_score(y_test,predicted))
# Out:
# MSE:  209273279990.3251
# R squared:  -0.588793024762889

# %%
#Polynomial regression example plot
x= df["sqft_living"].values.reshape(-1,1)
y= df["price"].values
poly = PolynomialFeatures(degree = 2) 
x_poly = poly.fit_transform(x) 
poly.fit(x_poly, y) 
lg=LinearRegression()
lg.fit(x_poly, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
plt.scatter(x, y, color="r")
plt.title("Linear regression")
plt.ylabel("space")
plt.xlabel("price")
plt.plot(x, lg.predict(poly.fit_transform(x)), color="k")
