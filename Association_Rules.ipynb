# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

dataset = [['Skirt', 'Sneakers', 'Scarf', 'Pants', 'Hat'],

    ['Sunglasses', 'Skirt', 'Sneakers', 'Pants', 'Hat'],

    ['Dress', 'Sandals', 'Scarf', 'Pants', 'Heels'],

    ['Dress', 'Necklace', 'Earrings', 'Scarf', 'Hat', 'Heels', 'Hat'],

   ['Earrings', 'Skirt', 'Skirt', 'Scarf', 'Shirt', 'Pants']]

# %%
data=dataset

# %%
from mlxtend.preprocessing import TransactionEncoder
te = TransactionEncoder()
te_data = te.fit(data).transform(data)
#print(te.columns_)
df = pd.DataFrame(te_data,columns=te.columns_)
df
# Out:
# ['Dress', 'Earrings', 'Hat', 'Heels', 'Necklace', 'Pants', 'Sandals', 'Scarf', 'Shirt', 'Skirt', 'Sneakers', 'Sunglasses']
#    Dress  Earrings    Hat  Heels  Necklace  Pants  Sandals  Scarf  Shirt  \
# 0  False     False   True  False     False   True    False   True  False
# 1  False     False   True  False     False   True    False  False  False
# 2   True     False  False   True     False   True     True   True  False
# 3   True      True   True   True      True  False    False   True  False
# 4  False      True  False  False     False   True    False   True   True
#
#    Skirt  Sneakers  Sunglasses
# 0   True      True       False
# 1   True      True        True
# 2  False     False       False
# 3  False     False       False
# 4   True     False       False

# %%
sns.countplot(x='Dress',data=df)
plt.show()

# %%
df.columns
# Out:
# Index(['Dress', 'Earrings', 'Hat', 'Heels', 'Necklace', 'Pants', 'Sandals',
#        'Scarf', 'Shirt', 'Skirt', 'Sneakers', 'Sunglasses'],
#       dtype='object')

# %%
print("Percentage Wise Count\n",df['Dress'].value_counts(normalize=True)*100)
print("\t")
print("Percentage Wise Count\n",df['Earrings'].value_counts(normalize=True)*100)
print("\t")
print("Percentage Wise Count\n",df['Hat'].value_counts(normalize=True)*100)
print("\t")
print("Percentage Wise Count\n",df['Heels'].value_counts(normalize=True)*100)
print("\t")
print("Percentage Wise Count\n",df['Necklace'].value_counts(normalize=True)*100)
print("\t")
print("Percentage Wise Count\n",df['Pants'].value_counts(normalize=True)*100)
print("\t")
print("Percentage Wise Count\n",df['Sandals'].value_counts(normalize=True)*100)
print("\t")
print("Percentage Wise Count\n",df['Scarf'].value_counts(normalize=True)*100)
print("\t")
print("Percentage Wise Count\n",df['Shirt'].value_counts(normalize=True)*100)
print("\t")
print("Percentage Wise Count\n",df['Skirt'].value_counts(normalize=True)*100)
print("\t")
print("Percentage Wise Count\n",df['Sneakers'].value_counts(normalize=True)*100)
print("\t")
print("Percentage Wise Count\n",df['Sunglasses'].value_counts(normalize=True)*100)
# Out:
# Percentage Wise Count
#  False    60.0
# True     40.0
# Name: Dress, dtype: float64
#
# Percentage Wise Count
#  False    60.0
# True     40.0
# Name: Earrings, dtype: float64
#
# Percentage Wise Count
#  True     60.0
# False    40.0
# Name: Hat, dtype: float64
#
# Percentage Wise Count
#  False    60.0
# True     40.0
# Name: Heels, dtype: float64
#
# Percentage Wise Count
#  False    80.0
# True     20.0
# Name: Necklace, dtype: float64
#
# Percentage Wise Count
#  True     80.0
# False    20.0
# Name: Pants, dtype: float64
#
# Percentage Wise Count
#  False    80.0
# True     20.0
# Name: Sandals, dtype: float64
#
# Percentage Wise Count
#  True     80.0
# False    20.0
# Name: Scarf, dtype: float64
#
# Percentage Wise Count
#  False    80.0
# True     20.0
# Name: Shirt, dtype: float64
#
# Percentage Wise Count
#  True     60.0
# False    40.0
# Name: Skirt, dtype: float64
#
# Percentage Wise Count
#  False    60.0
# True     40.0
# Name: Sneakers, dtype: float64
#
# ...

# %%
from mlxtend.frequent_patterns import apriori

df1 = apriori(df,min_support=0.01,use_colnames=True)
df1
# Out:
#      support                                        itemsets
# 0        0.4                                         (Dress)
# 1        0.4                                      (Earrings)
# 2        0.6                                           (Hat)
# 3        0.4                                         (Heels)
# 4        0.2                                      (Necklace)
# ..       ...                                             ...
# 146      0.2         (Earrings, Hat, Heels, Scarf, Necklace)
# 147      0.2          (Earrings, Pants, Skirt, Scarf, Shirt)
# 148      0.2            (Pants, Skirt, Sneakers, Hat, Scarf)
# 149      0.2       (Sunglasses, Pants, Skirt, Sneakers, Hat)
# 150      0.2  (Earrings, Hat, Heels, Scarf, Necklace, Dress)
#
# [151 rows x 2 columns]

# %%
df1.sort_values(by="support",ascending=False)
# Out:
#      support                                        itemsets
# 5        0.8                                         (Pants)
# 7        0.8                                         (Scarf)
# 2        0.6                                           (Hat)
# 9        0.6                                         (Skirt)
# 39       0.6                                  (Pants, Scarf)
# ..       ...                                             ...
# 56       0.2                             (Hat, Heels, Dress)
# 55       0.2                        (Scarf, Dress, Earrings)
# 54       0.2                     (Necklace, Dress, Earrings)
# 53       0.2                        (Heels, Dress, Earrings)
# 150      0.2  (Earrings, Hat, Heels, Scarf, Necklace, Dress)
#
# [151 rows x 2 columns]

# %%
df1['length'] = df1['itemsets'].apply(lambda x:len(x))
df1
# Out:
#      support                                        itemsets  length
# 0        0.4                                         (Dress)       1
# 1        0.4                                      (Earrings)       1
# 2        0.6                                           (Hat)       1
# 3        0.4                                         (Heels)       1
# 4        0.2                                      (Necklace)       1
# ..       ...                                             ...     ...
# 146      0.2         (Earrings, Hat, Heels, Scarf, Necklace)       5
# 147      0.2          (Earrings, Pants, Skirt, Scarf, Shirt)       5
# 148      0.2            (Pants, Skirt, Sneakers, Hat, Scarf)       5
# 149      0.2       (Sunglasses, Pants, Skirt, Sneakers, Hat)       5
# 150      0.2  (Earrings, Hat, Heels, Scarf, Necklace, Dress)       6
#
# [151 rows x 3 columns]

# %%
df1[(df1['length']==2) & (df1['support']>=0.05)]
# Out:
#     support                itemsets  length
# 12      0.2       (Dress, Earrings)       2
# 13      0.2            (Hat, Dress)       2
# 14      0.4          (Heels, Dress)       2
# 15      0.2       (Necklace, Dress)       2
# 16      0.2          (Pants, Dress)       2
# 17      0.2        (Sandals, Dress)       2
# 18      0.4          (Scarf, Dress)       2
# 19      0.2         (Hat, Earrings)       2
# 20      0.2       (Heels, Earrings)       2
# 21      0.2    (Necklace, Earrings)       2
# 22      0.2       (Pants, Earrings)       2
# 23      0.4       (Scarf, Earrings)       2
# 24      0.2       (Shirt, Earrings)       2
# 25      0.2       (Skirt, Earrings)       2
# 26      0.2            (Hat, Heels)       2
# 27      0.2         (Hat, Necklace)       2
# 28      0.4            (Pants, Hat)       2
# 29      0.4            (Hat, Scarf)       2
# 30      0.4            (Skirt, Hat)       2
# 31      0.4         (Sneakers, Hat)       2
# ...

# %%
#data = list(df["products"].apply(lambda x:x.split(',')))

# %%
#df=pd.DataFrame(dataset)

# %%
import mlxtend
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
te=TransactionEncoder()
te_ary=te.fit(dataset).transform(dataset)    #Apply one-hot-encoding on our dataset
df=pd.DataFrame(te_ary, columns=te.columns_)  #Creating a new DataFrame from our Numpy array
df
# Out:
#    Dress  Earrings    Hat  Heels  Necklace  Pants  Sandals  Scarf  Shirt  \
# 0  False     False   True  False     False   True    False   True  False
# 1  False     False   True  False     False   True    False  False  False
# 2   True     False  False   True     False   True     True   True  False
# 3   True      True   True   True      True  False    False   True  False
# 4  False      True  False  False     False   True    False   True   True
#
#    Skirt  Sneakers  Sunglasses
# 0   True      True       False
# 1   True      True        True
# 2  False     False       False
# 3  False     False       False
# 4   True     False       False

# %%
from mlxtend.frequent_patterns import apriori
apriori(df, min_support=0.6)
# Out:
#    support itemsets
# 0      0.6      (2)
# 1      0.8      (5)
# 2      0.8      (7)
# 3      0.6      (9)
# 4      0.6   (5, 7)
# 5      0.6   (9, 5)

# %%
frequent_itemsets=apriori(df, min_support=0.6, use_colnames=True) #Instead of column indices we can use column names.
frequent_itemsets
# Out:
#    support        itemsets
# 0      0.6           (Hat)
# 1      0.8         (Pants)
# 2      0.8         (Scarf)
# 3      0.6         (Skirt)
# 4      0.6  (Pants, Scarf)
# 5      0.6  (Pants, Skirt)

# %%
from mlxtend.frequent_patterns import association_rules 
association_rules(frequent_itemsets,metric="confidence",min_threshold=0.7) # associate itemsets with confidence over 70%.
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0     (Pants)     (Scarf)                 0.8                 0.8      0.6
# 1     (Scarf)     (Pants)                 0.8                 0.8      0.6
# 2     (Pants)     (Skirt)                 0.8                 0.6      0.6
# 3     (Skirt)     (Pants)                 0.6                 0.8      0.6
#
#    confidence    lift  leverage  conviction
# 0        0.75  0.9375     -0.04         0.8
# 1        0.75  0.9375     -0.04         0.8
# 2        0.75  1.2500      0.12         1.6
# 3        1.00  1.2500      0.12         inf

# %%
from mlxtend.frequent_patterns import association_rules 
association_rules(frequent_itemsets,metric="lift",min_threshold=1.25)
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0     (Skirt)     (Pants)                 0.6                 0.8      0.6
#
#    confidence  lift  leverage  conviction
# 0         1.0  1.25      0.12         inf

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('Market_Basket_Optimisation.csv',sep=',')
df.head()
# Out:
#            shrimp    almonds     avocado    vegetables mix green grapes  \
# 0         burgers  meatballs        eggs               NaN          NaN
# 1         chutney        NaN         NaN               NaN          NaN
# 2          turkey    avocado         NaN               NaN          NaN
# 3   mineral water       milk  energy bar  whole wheat rice    green tea
# 4  low fat yogurt        NaN         NaN               NaN          NaN
#
#   whole weat flour yams cottage cheese energy drink tomato juice  \
# 0              NaN  NaN            NaN          NaN          NaN
# 1              NaN  NaN            NaN          NaN          NaN
# 2              NaN  NaN            NaN          NaN          NaN
# 3              NaN  NaN            NaN          NaN          NaN
# 4              NaN  NaN            NaN          NaN          NaN
#
#   low fat yogurt green tea honey salad mineral water salmon antioxydant juice  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   shrimp             7500 non-null   object
#  1   almonds            5746 non-null   object
#  2   avocado            4388 non-null   object
#  3   vegetables mix     3344 non-null   object
#  4   green grapes       2528 non-null   object
#  5   whole weat flour   1863 non-null   object
#  6   yams               1368 non-null   object
#  7   cottage cheese     980 non-null    object
#  8   energy drink       653 non-null    object
#  9   tomato juice       394 non-null    object
#  10  low fat yogurt     255 non-null    object
#  11  green tea          153 non-null    object
#  12  honey              86 non-null     object
#  13  salad              46 non-null     object
#  14  mineral water      24 non-null     object
#  15  salmon             7 non-null      object
# ...

# %%
print('Percent of missing "olive oil" records is %.2f%%' %((df['olive oil'].isnull().sum()/df.shape[0])*100))
print('Percent of missing "spinach" records is %.2f%%' %((df['spinach'].isnull().sum()/df.shape[0])*100))
print('Percent of missing "frozen smoothie" records is %.2f%%' %((df['frozen smoothie'].isnull().sum()/df.shape[0])*100))
print('Percent of missing "antioxydant juice" records is %.2f%%' %((df['antioxydant juice'].isnull().sum()/df.shape[0])*100))
print('Percent of missing "salmon" records is %.2f%%' %((df['salmon'].isnull().sum()/df.shape[0])*100))
print('Percent of missing "mineral water" records is %.2f%%' %((df['mineral water'].isnull().sum()/df.shape[0])*100))
print('Percent of missing "salad" records is %.2f%%' %((df['salad'].isnull().sum()/df.shape[0])*100))
print('Percent of missing "honey" records is %.2f%%' %((df['honey'].isnull().sum()/df.shape[0])*100))
print('Percent of missing "green tea" records is %.2f%%' %((df['green tea'].isnull().sum()/df.shape[0])*100))
print('Percent of missing "low fat yogurt" records is %.2f%%' %((df['low fat yogurt'].isnull().sum()/df.shape[0])*100))
print('Percent of missing "tomato juice" records is %.2f%%' %((df['tomato juice'].isnull().sum()/df.shape[0])*100))
print('Percent of missing "energy drink" records is %.2f%%' %((df['energy drink'].isnull().sum()/df.shape[0])*100))
print('Percent of missing "cottage cheese" records is %.2f%%' %((df['cottage cheese'].isnull().sum()/df.shape[0])*100))
print('Percent of missing "yams" records is %.2f%%' %((df['yams'].isnull().sum()/df.shape[0])*100))
print('Percent of missing "whole weat flour" records is %.2f%%' %((df['whole weat flour'].isnull().sum()/df.shape[0])*100))
print('Percent of missing "green grapes" records is %.2f%%' %((df['green grapes'].isnull().sum()/df.shape[0])*100))
print('Percent of missing "vegetables mix" records is %.2f%%' %((df['vegetables mix'].isnull().sum()/df.shape[0])*100))
print('Percent of missing "avocado" records is %.2f%%' %((df['avocado'].isnull().sum()/df.shape[0])*100))
print('Percent of missing "almonds" records is %.2f%%' %((df['almonds'].isnull().sum()/df.shape[0])*100))
print('Percent of missing "shrimp" records is %.2f%%' %((df['shrimp'].isnull().sum()/df.shape[0])*100))
# Out:
# Percent of missing "olive oil" records is 100.00%
# Percent of missing "spinach" records is 99.97%
# Percent of missing "frozen smoothie" records is 99.96%
# Percent of missing "antioxydant juice" records is 99.96%
# Percent of missing "salmon" records is 99.91%
# Percent of missing "mineral water" records is 99.68%
# Percent of missing "salad" records is 99.39%
# Percent of missing "honey" records is 98.85%
# Percent of missing "green tea" records is 97.96%
# Percent of missing "low fat yogurt" records is 96.60%
# Percent of missing "tomato juice" records is 94.75%
# Percent of missing "energy drink" records is 91.29%
# Percent of missing "cottage cheese" records is 86.93%
# Percent of missing "yams" records is 81.76%
# Percent of missing "whole weat flour" records is 75.16%
# Percent of missing "green grapes" records is 66.29%
# Percent of missing "vegetables mix" records is 55.41%
# Percent of missing "avocado" records is 41.49%
# Percent of missing "almonds" records is 23.39%
# ...

# %%
#df.replace(["n.a","?","NaN"], np.nan, inplace=True)
df.drop(columns=['olive oil', 'spinach', 'frozen smoothie', 'antioxydant juice','salmon', 'mineral water', 'salad', 'honey', 'green tea','low fat yogurt', 'tomato juice', 'energy drink', 'cottage cheese', 'yams','whole weat flour','green grapes','vegetables mix'],inplace=True)

# %%
df.head()
# Out:
#            shrimp    almonds     avocado
# 0         burgers  meatballs        eggs
# 1         chutney        NaN         NaN
# 2          turkey    avocado         NaN
# 3   mineral water       milk  energy bar
# 4  low fat yogurt        NaN         NaN

# %%
df["avocado"] = df["avocado"].replace(np.nan, "NaN")
df["shrimp"] = df["shrimp"].replace(np.nan, "NaN")
df["almonds"] = df["almonds"].replace(np.nan, "NaN")

# %%
df1 = df.values.tolist()

# %%
df1
# Out:
# [['burgers', 'meatballs', 'eggs'],
#  ['chutney', 'NaN', 'NaN'],
#  ['turkey', 'avocado', 'NaN'],
#  ['mineral water', 'milk', 'energy bar'],
#  ['low fat yogurt', 'NaN', 'NaN'],
#  ['whole wheat pasta', 'french fries', 'NaN'],
#  ['soup', 'light cream', 'shallot'],
#  ['frozen vegetables', 'spaghetti', 'green tea'],
#  ['french fries', 'NaN', 'NaN'],
#  ['eggs', 'pet food', 'NaN'],
#  ['cookies', 'NaN', 'NaN'],
#  ['turkey', 'burgers', 'mineral water'],
#  ['spaghetti', 'champagne', 'cookies'],
#  ['mineral water', 'salmon', 'NaN'],
#  ['mineral water', 'NaN', 'NaN'],
#  ['shrimp', 'chocolate', 'chicken'],
#  ['turkey', 'eggs', 'NaN'],
#  ['turkey', 'fresh tuna', 'tomatoes'],
#  ['meatballs', 'milk', 'honey'],
#  ['red wine', 'shrimp', 'pasta'],
#  ['rice', 'sparkling water', 'NaN'],
#  ['spaghetti', 'mineral water', 'ham'],
#  ['burgers', 'grated cheese', 'shrimp'],
#  ['eggs', 'NaN', 'NaN'],
#  ['parmesan cheese', 'spaghetti', 'soup'],
# ...

# %%
import mlxtend
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder

te=TransactionEncoder()
te_ary=te.fit(df1).transform(df1)    #Apply one-hot-encoding on our dataset
df=pd.DataFrame(te_ary, columns=te.columns_)  #Creating a new DataFrame from our Numpy array
df
# Out:
#         NaN  almonds  antioxydant juice  asparagus  avocado  babies food  \
# 0     False    False              False      False    False        False
# 1      True    False              False      False    False        False
# 2      True    False              False      False     True        False
# 3     False    False              False      False    False        False
# 4      True    False              False      False    False        False
# ...     ...      ...                ...        ...      ...          ...
# 7495  False    False              False      False    False        False
# 7496  False    False              False      False    False        False
# 7497   True    False              False      False    False        False
# 7498   True    False              False      False    False        False
# 7499  False    False              False      False    False        False
#
#       bacon  barbecue sauce  black tea  blueberries  ...  turkey  \
# ...

# %%
from mlxtend.frequent_patterns import apriori

apriori(df, min_support=0.1)
# Out:
#     support itemsets
# 0  0.414933      (0)
# 1  0.105067     (25)
# 2  0.107467     (37)
# 3  0.191467     (72)
# 4  0.139200     (99)

# %%
frequent_itemsets=apriori(df, min_support=0.1, use_colnames=True) #Instead of column indices we can use column names.
frequent_itemsets
# Out:
#     support         itemsets
# 0  0.414933            (NaN)
# 1  0.105067      (chocolate)
# 2  0.107467           (eggs)
# 3  0.191467  (mineral water)
# 4  0.139200      (spaghetti)

# %%
from mlxtend.frequent_patterns import association_rules 
association_rules(frequent_itemsets,metric="confidence",min_threshold=0.0) # associate itemsets with confidence over 70%.
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction]
# Index: []

# %%
from mlxtend.frequent_patterns import association_rules 
association_rules(frequent_itemsets,metric="lift",min_threshold=0.1)
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction]
# Index: []

# %%
df.shape
# Out:
# (7500, 26)

# %%
df.isna().sum()
# Out:
# shrimp                  0
# almonds              1754
# avocado              3112
# vegetables mix       4156
# green grapes         4972
# whole weat flour     5637
# yams                 6132
# cottage cheese       6520
# energy drink         6847
# tomato juice         7106
# low fat yogurt       7245
# green tea            7347
# honey                7414
# salad                7454
# mineral water        7476
# salmon               7493
# antioxydant juice    7497
# frozen smoothie      7497
# spinach              7498
# olive oil            7500
# dtype: int64

# %%
df.describe(include='all')
# Out:
#                shrimp        almonds        avocado vegetables mix  \
# count            7500           5746           4388           3344
# unique            115            117            115            114
# top     mineral water  mineral water  mineral water  mineral water
# freq              577            484            375            201
# mean              NaN            NaN            NaN            NaN
# std               NaN            NaN            NaN            NaN
# min               NaN            NaN            NaN            NaN
# 25%               NaN            NaN            NaN            NaN
# 50%               NaN            NaN            NaN            NaN
# 75%               NaN            NaN            NaN            NaN
# max               NaN            NaN            NaN            NaN
#
#        green grapes whole weat flour       yams cottage cheese energy drink  \
# count          2528             1863       1368            980          653
# ...

# %%
df.columns
# Out:
# Index(['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes',
#        'whole weat flour', 'yams', 'cottage cheese', 'energy drink',
#        'tomato juice', 'low fat yogurt', 'green tea', 'honey', 'salad',
#        'mineral water', 'salmon', 'antioxydant juice', 'frozen smoothie',
#        'spinach', 'olive oil'],
#       dtype='object')

# %%
df.head(1)
# Out:
#     shrimp    almonds avocado vegetables mix green grapes whole weat flour  \
# 0  burgers  meatballs    eggs            NaN          NaN              NaN
#
#   yams cottage cheese energy drink tomato juice low fat yogurt green tea  \
# 0  NaN            NaN          NaN          NaN            NaN       NaN
#
#   honey salad mineral water salmon antioxydant juice frozen smoothie spinach  \
# 0   NaN   NaN           NaN    NaN               NaN             NaN     NaN
#
#    olive oil
# 0        NaN

# %%
#df['shrimp'].nunique()
